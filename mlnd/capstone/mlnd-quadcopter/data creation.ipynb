# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn  as sns
from IPython.display import display
import gc
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os




class Data:
    def __init__(self):
        self.datadir = "/data/stocks/"
        
    def save(self, df, symbol, frequency ):
        file = "{}{}_{}.parquet.gzip".format(self.datadir,symbol,frequency )
        df.to_parquet(file, compression='gzip')
        
    def get(self, symbol, frequency):
        file = "{}{}_{}.parquet.gzip".format(self.datadir,symbol,frequency)
        return pd.read_parquet(file)
    
def read_in_chunks():
    allSymbol = []
    for chunk in pd.read_csv(datadir+'historical_minute.csv', chunksize=100000):
    #     chunk.loc[(chunk.tradingsymbol == symbol)]
        allSymbol.append(chunk.tradingsymbol.unique())

# %%
# %%time
# Data().get('MRF', 'minute')
# df = pd.read_csv('/data/stocks/instruments.csv')
nifty200 = Data().get('NSE', 'nifty200list')

nifty200.to_csv("/data/stocks/NSE_nifty200list.csv")

# %%
# %%time
Data().get('nse', 'instruments')
# Out:
# CPU times: user 20.2 ms, sys: 4.37 ms, total: 24.5 ms
# Wall time: 20.2 ms
#                tradingsymbol  high  open  datetime  volume instrument_type  \
# 0             EURINR16JUNFUT   NaN   NaN       NaN     NaN             FUT
# 1      BANKNIFTY1660215800CE   NaN   NaN       NaN     NaN              CE
# 2                  20MICRONS   NaN   NaN       NaN     NaN              EQ
# 3      BANKNIFTY1660215800PE   NaN   NaN       NaN     NaN              PE
# 4               JAIA16JULFUT   NaN   NaN       NaN     NaN             FUT
# 5                   A2ZINFRA   NaN   NaN       NaN     NaN              EQ
# 6                 AARTIDRUGS   NaN   NaN       NaN     NaN              EQ
# 7                   AARTIIND   NaN   NaN       NaN     NaN              EQ
# 8                   DRREDDY*   NaN   NaN       NaN     NaN              EQ
# 9               JARL16JULFUT   NaN   NaN       NaN     NaN             FUT
# ...

# %%
appended_data = []
for chunk in pd.read_csv(datadir+'historical_minute.csv', chunksize=100000):
    df = chunk[chunk['tradingsymbol'].isin(nifty200)]
    if not df.empty:
        appended_data.append(df)

# %%
df = Data().get('nifty200', 'minute')#pd.read_parquet(datadir+'_minute.parquet.gzip')
# for symbol in nifty200:
#     df1 = df.loc[(df.tradingsymbol == symbol)]
#     df1.to_parquet(datadir+symbol+'_minute.parquet.gzip', compression='gzip')

# %%
print(df.datetime.min())
print(df.datetime.max())
# Out:
# 2015-09-01 03:45:00+00:00
# 2016-06-23 09:59:00+00:00
